# %% [markdown]
# <a href="https://colab.research.google.com/github/kuntalKOLE/ML_Supervised_Algorithms/blob/KNN/KNN_2%2C_Sep_23%2C_2024.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # Interview Questions

# %% [markdown]
# ### 1. **Question:**
# In **gradient descent**, if the learning rate is set too high, which subtle behavior might be observed?
#
# - A) The gradient descent steps become perfectly aligned with the negative gradient, ensuring guaranteed convergence in fewer epochs.
# - B) The cost function values bounce chaotically or even increase over time, failing to converge.
# - C) The algorithm accelerates initially but always slows dramatically when near a minimum.
# - D) The convergence speed remains unaffected by learning rate adjustments.
#
# <br>
# <br>
# <br>
# <br>
# <br>
# <br>
#
# **Correct Answer:** B) The cost function values bounce chaotically or even increase over time, failing to converge
# **Explanation:**
# A too-large learning rate can overshoot minima, causing the updates to jump inconsistently and possibly diverge. This behavior appears as oscillations or growing cost values rather than smooth descent.
#
# ---
#
# ### 2. **Question:**
# When implementing **stochastic gradient descent (SGD)** for a large-scale linear regression problem, which nuanced pitfall might occur?
#
# - A) Batching the data in extremely small batches always guarantees faster convergence and better minima.
# - B) The estimator might exhibit high variance in the weight updates, requiring careful tuning of learning rate and batch size.
# - C) Convergence is guaranteed after a finite number of iterations, independent of the dataset size.
# - D) The weight updates are identical for all samples, making it impossible to differentiate among them.
#
# <br>
# <br>
# <br>
# <br>
# <br>
# <br>
#
# **Correct Answer:** B) The estimator might exhibit high variance in the weight updates, requiring careful tuning of learning rate and batch size
# **Explanation:**
# SGD updates are computed from one or a few samples at a time, which can fluctuate significantly compared to full-batch methods. A well-chosen learning rate and batch size can mitigate this variance and improve stability.
#
# ---
#
# ### 3. **Question:**
# A team tries **mini-batch gradient descent** on linear regression but notices the validation error plateaus at a suboptimal level. Which less obvious explanation might account for this?
#
# - A) The batch size is too large, leading to constant changes in the gradient direction.
# - B) Momentum terms in mini-batch gradient descent eliminate the effect of local minima.
# - C) An unnecessarily small learning rate can trap the model in a shallow region of the loss landscape.
# - D) The model’s hypothesis space has shrunk due to using fewer data points overall.
#
# <br>
# <br>
# <br>
# <br>
# <br>
# <br>
#
# **Correct Answer:** C) An unnecessarily small learning rate can trap the model in a shallow region of the loss landscape
# **Explanation:**
# Using mini-batches doesn’t alone guarantee finding a global optimum. A small learning rate may prevent the model from escaping near-flat regions or shallow minima, leading to stagnation.
#
# ---
#
# ### 5. **Question:**
# When fitting **linear regression** on a dataset with outliers, which subtle effect can occur?
#
# - A) Gradual removal of outliers during gradient descent iterations.
# - B) Outliers have negligible impact since linear regression always focuses on the median of residuals.
# - C) Large errors from outliers can disproportionately affect the cost function, distorting the regression line.
# - D) Outliers get automatically truncated if using standard matrix inversion methods.
#
# <br>
# <br>
# <br>
# <br>
# <br>
# <br>
#
# **Correct Answer:** C) Large errors from outliers can disproportionately affect the cost function, distorting the regression line
# **Explanation:**
# Ordinary Least Squares penalizes squared residuals, so outliers with large residuals carry disproportionate weight, potentially skewing the fitted line away from the majority of data points.
#
# ---
#
# ### 6. **Question:**
# During **logistic regression** training, you notice the cost function suddenly starts increasing after a few epochs, even though it initially decreased. Which nuanced reason might explain this phenomenon?
#
# - A) Logistic regression cost functions are non-convex, so local minima cause indefinite oscillations.
# - B) The learning rate might be too high, causing overshooting even in a mostly convex landscape.
# - C) The model saturates the gradient to zero for all points, making cost calculation unreliable.
# - D) Logistic regression spontaneously re-initializes its parameters to random values during training.
#
# <br>
# <br>
# <br>
# <br>
# <br>
# <br>
#
# **Correct Answer:** B) The learning rate might be too high, causing overshooting even in a mostly convex landscape
# **Explanation:**
# Logistic regression’s cost function is convex. However, if the step size is large, gradient descent can overshoot, causing increases in cost rather than continued decrease.
#
# ---
#
# ### 7. **Question:**
# Consider a **logistic regression** model predicting a rare disease (positive class is rare). If you strictly optimize for accuracy, which subtle outcome could occur?
#
# - A) The model will predict positive for nearly all patients, maximizing recall automatically.
# - B) The model might simply predict negative for everyone, achieving high accuracy but very low recall.
# - C) The confusion matrix becomes perfectly balanced, enhancing interpretability.
# - D) Accuracy maximization naturally increases the F1 score for rare classes.
#
# <br>
# <br>
# <br>
# <br>
# <br>
# <br>
#
# **Correct Answer:** B) The model might simply predict negative for everyone, achieving high accuracy but very low recall
# **Explanation:**
# When positives are rare, predicting all negatives may yield high overall accuracy but fails to catch most positives. This underscores why metrics like recall or F1 score can be more meaningful in imbalanced settings.
#
# ---
#
# ### 8. **Question:**
# You apply **logistic regression** to a binary classification task. The model’s predicted probabilities are consistently near 0.5 for most samples. Which subtle factor could be driving this behavior?
#
# - A) The model strongly separates classes but randomly selects probabilities for each instance.
# - B) The feature set might be uninformative or not scaled correctly, limiting the model’s ability to push the log-odds away from zero.
# - C) Logistic regression always initializes the probability to 0.5 as a fixed prior, which never changes.
# - D) This scenario is impossible unless the dataset is perfectly linearly separable.
#
# <br>
# <br>
# <br>
# <br>
# <br>
# <br>
#
# **Correct Answer:** B) The feature set might be uninformative or not scaled correctly, limiting the model’s ability to push the log-odds away from zero
# **Explanation:**
# If features have minimal discriminative power or are improperly scaled, logistic regression’s learned weights stay near zero, yielding predicted probabilities close to 0.5 for most samples.
#
# ---
#
# ### 9. **Question:**
# Your **logistic regression** model has a high recall but very low precision. Which subtle conclusion might best describe your model’s predictions?
#
# - A) The model rarely identifies positives and misses most actual positives.
# - B) The model doesn’t predict positives frequently, but when it does, they are almost always correct.
# - C) The model frequently flags instances as positive, catching many real positives but also producing numerous false alarms.
# - D) The model is balanced across both false positives and false negatives.
#
# <br>
# <br>
# <br>
# <br>
# <br>
# <br>
#
# **Correct Answer:** C) The model frequently flags instances as positive, catching many real positives but also producing numerous false alarms
# **Explanation:**
# High recall and low precision means the model is capturing most of the true positives (few false negatives) but also has many false positives, lowering precision.
#
# ---
#
# ### 10. **Question:**
# When adjusting the decision threshold to improve **precision**, which trade-off is commonly observed?
#
# - A) Decreasing the threshold boosts both precision and recall simultaneously.
# - B) Increasing the threshold can reduce recall while increasing precision.
# - C) Lowering the threshold reduces the number of positives predicted, driving precision higher.
# - D) Adjusting the threshold has no effect on the precision-recall relationship.
#
# <br>
# <br>
# <br>
# <br>
# <br>
# <br>
#
# **Correct Answer:** B) Increasing the threshold can reduce recall while increasing precision
# **Explanation:**
# Raising the decision threshold typically means predicting positive only for more confident cases, thus reducing the number of positives (potentially lowering recall) but improving precision by filtering out uncertain positives.
#
# ---
#
# ### 11. **Question:**
# You have a binary classifier and you’re comparing two models using **precision-recall curves**. Model A’s curve is mostly above Model B’s, except for a small region where B’s curve is higher. Which subtle recommendation might be valid?
#
# - A) Model A is definitively worse because it has any region below Model B’s curve.
# - B) It’s beneficial to pick a threshold from the region where Model A’s PR curve is lower than B’s.
# - C) The best practical decision depends on the specific precision-recall trade-off that matters for the application.
# - D) If Model A is better overall except in a small region, it indicates a random chance phenomenon.
#
# <br>
# <br>
# <br>
# <br>
# <br>
# <br>
#
# **Correct Answer:** C) The best practical decision depends on the specific precision-recall trade-off that matters for the application
# **Explanation:**
# Precision-recall curves can intersect. The model choice depends on which balance of precision and recall is most important for the task. A model with a generally better curve might still be outperformed in specific thresholds where the other model excels.
#
# ---
#
# ### 12. **Question:**
# In **precision/recall** terms, which scenario might produce a deceptively high precision score?
#
# - A) A very low number of predicted positives, all of which happen to be correct.
# - B) Predicting all samples as positive, thus ensuring almost no false negatives.
# - C) A large dataset with many true positives dominating the confusion matrix.
# - D) Balancing false positives and false negatives always leads to elevated precision.
#
# <br>
# <br>
# <br>
# <br>
# <br>
# <br>
#
# **Correct Answer:** A) A very low number of predicted positives, all of which happen to be correct
# **Explanation:**
# Precision measures $\frac{\text{true positives}}{\text{predicted positives}}$. Predicting very few positives can inflate precision if those few predictions are accurate, yet it may ignore many actual positives (harming recall).
#
# ---
#
# ### 13. **Question:**
# A data scientist claims that **increasing the training data size** always improves the performance of a **gradient descent**-based linear model. Which nuanced counterexample best disproves this claim?
#
# - A) Adding irrelevant features to the model can degrade accuracy.
# - B) Introducing more data points of the same distribution without additional signal might not improve results significantly.
# - C) Gradient descent fails to update weights if the number of data points is large.
# - D) More data always leads to overfitting in linear models.
#
# <br>
# <br>
# <br>
# <br>
# <br>
# <br>
#
# **Correct Answer:** B) Introducing more data points of the same distribution without additional signal might not improve results significantly
# **Explanation:**
# Simply adding more samples from the same distribution won’t always yield performance gains, especially if the data lacks new information. Performance plateaus once you’ve adequately modeled the underlying relationships.
#
# ---
#
# ### 14. **Question:**
# When interpreting **linear regression** coefficients, which subtle phenomenon can mislead about a variable’s importance?
#
# - A) Standardizing the features eliminates all interpretability of coefficients.
# - B) If some features are correlated, the coefficients may shift to absorb shared variance, under- or overestimating a feature’s true effect.
# - C) Negative coefficient signs automatically mean there’s an inverse causal relationship.
# - D) Large absolute coefficients always indicate the most significant predictors.
#
# <br>
# <br>
# <br>
# <br>
# <br>
# <br>
#
# **Correct Answer:** B) If some features are correlated, the coefficients may shift to absorb shared variance, under- or overestimating a feature’s true effect
# **Explanation:**
# Multicollinearity can cause coefficient values to fluctuate depending on which correlated variables are included. This complicates interpretation, since the effect attributed to one variable might partially belong to another correlated feature.
#
# ---
#
# ### 15. **Question:**
# In **logistic regression**, you check your model’s predicted probabilities and see that they never exceed 0.9 nor go below 0.1, despite the data being reasonably separable. Which subtle reason could explain this?
#
# - A) The sigmoid function saturates for all data points, forcing probabilities to the extremes of 0 or 1.
# - B) Missing regularization leads to infinite slope in the decision boundary, pushing probabilities to 0 or 1.
# - C) L2 regularization on the weights can constrain the magnitude of the coefficients, limiting the range of predicted probabilities.
# - D) Logistic regression discretizes continuous outputs by design, restricting probabilities to [0.1, 0.9].
#
# <br>
# <br>
# <br>
# <br>
# <br>
# <br>
#
# **Correct Answer:** C) L2 regularization on the weights can constrain the magnitude of the coefficients, limiting the range of predicted probabilities
# **Explanation:**
# With strong regularization, coefficients remain small in absolute value. This flattens the logistic curve near decision boundaries, restricting predicted probabilities from reaching very close to 0 or 1.

# %% [markdown]
# # BlinkIt Case Study

# %%
import pandas as pd
import numpy as np

# !gdown 1ZdhRqYv-JizWV6DxO6C4R_k1kxPhmlF2
# Out:
# Downloading...
# From: https://drive.google.com/uc?id=1ZdhRqYv-JizWV6DxO6C4R_k1kxPhmlF2
# To: /content/multiclass.csv
# 100% 14.6k/14.6k [00:00<00:00, 22.6MB/s]

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %%
df=pd.read_csv('multiclass.csv')
df.head()
# Out:
#    Region  Fresh  Milk  Grocery  Frozen  Detergents_Paper  Delicassen  class
# 0       3  12669  9656     7561     214              2674        1338      2
# 1       3   7057  9810     9568    1762              3293        1776      2
# 2       3   6353  8808     7684    2405              3516        7844      2
# 3       3  13265  1196     4221    6404               507        1788      1
# 4       3  22615  5410     7198    3915              1777        5185      1

# %%
import seaborn as sns
import matplotlib.pyplot as plt

sns.histplot(data=df, x="class")
plt.title('Data Distribution')
plt.show()

# %%
X=df[['Region', 'Fresh', 'Milk', 'Grocery',  'Frozen',   'Detergents_Paper', 'Delicassen'    ]].copy()
y=df[['class']].copy()

# %%
from sklearn.decomposition import PCA
import matplotlib.pyplot as plt

# %%
def scatter_visualize(visualize1,visualize2,y_label):
  scatter = plt.scatter(visualize[:,0] ,visualize[:,1],c = y.values[:,0] )
  plt.legend(handles=scatter.legend_elements()[0], labels=['Class1','Class2','Class3'])
  plt.show()

# reducing features to just 2 features for visualization purpose
pca = PCA(n_components=2)
visualize = pca.fit_transform(X)


scatter_visualize(visualize[:,0] ,visualize[:,1],y.values[:,0])

# %%
from sklearn.model_selection import train_test_split
import matplotlib.pyplot as plt

X_train_val, X_test, y_train_val, y_test = train_test_split(X,y,test_size=0.25, random_state=42)

X_train, X_val, y_train, y_val = train_test_split(X_train_val,y_train_val,test_size=0.25, random_state=42)

print(X_train.shape, y_train.shape)
print(X_val.shape, y_val.shape)
print(X_test.shape, y_test.shape)
# Out:
# (247, 7) (247, 1)
# (83, 7) (83, 1)
# (110, 7) (110, 1)

# %%
from imblearn.over_sampling import SMOTE

# Create an instance of SMOTE
smt = SMOTE()

X_sm, y_sm = smt.fit_resample(X_train, y_train)

y_sm.value_counts()
# Out:
# class
# 1        99
# 2        99
# 3        99
# Name: count, dtype: int64

# %%
from sklearn.preprocessing import StandardScaler

st =  StandardScaler()

X_sm = st.fit_transform(X_sm.values)
X_val_scaled = st.transform(X_val.values)
X_test_scaled = st.transform(X_test.values)

y_sm = y_sm.values[:,0]
y_val = y_val.values[:,0]
y_test = y_test.values[:,0]

# %% [markdown]
# # Hyper-parameters for K-means

# %%
# import knn from sklearn
from sklearn.neighbors import KNeighborsClassifier

# %%
Acc = []

# Calculating error for K values between 1 and 50
# Note: 51 is not included in the loop
for i in range(1, 51):
    knn = KNeighborsClassifier(n_neighbors=i,metric='euclidean')
    knn.fit(X_sm, y_sm)

    Acc.append(knn.score(X_val_scaled,y_val))

# %%
plt.figure(figsize=(12, 6))
plt.plot(range(1, 51), Acc, color='red', linestyle='dashed', marker='o',
         markerfacecolor='blue', markersize=10)
plt.title('Accuracy of K Value')
plt.xlabel('K Value')
plt.ylabel('Accuracy')
# Out:
# Text(0, 0.5, 'Accuracy')

# %%
import matplotlib.pyplot as plt
from sklearn.inspection import DecisionBoundaryDisplay
from sklearn.neighbors import KNeighborsClassifier

# Choosing the first 2 columns for the plot


pca = PCA(n_components=2)
X_train_cols = pca.fit_transform(X_sm)

# Creating and fitting the tree classifier

classifier = KNeighborsClassifier(n_neighbors=5,metric='euclidean')

classifier.fit(X_train_cols, y_sm)

# Plotting the tree boundaries
disp = DecisionBoundaryDisplay.from_estimator(classifier,
                                              X_train_cols,
                                              response_method="predict",
                                              xlabel='f1', ylabel='f2',
                                              alpha=0.5,
                                              cmap=plt.cm.coolwarm)

# Plotting the data points
disp.ax_.scatter(X_train_cols[:, 0], X_train_cols[:, 1],
                 c=y_sm, edgecolor="k",
                 cmap=plt.cm.coolwarm)


plt.show()

# %% [markdown]
# ## Knn imputation

# %%
# !gdown 1vDIXh1yJxLpmgdh3gZGM6WX0u3GCPuIS
# Out:
# Downloading...
# From: https://drive.google.com/uc?id=1vDIXh1yJxLpmgdh3gZGM6WX0u3GCPuIS
# To: /content/knn_imputation.csv
# 100% 12.9k/12.9k [00:00<00:00, 18.0MB/s]

# %%
import pandas as pd
import numpy as np

df_imp = pd.read_csv('knn_imputation.csv')
df_imp.drop(['Unnamed: 0'],axis=1,inplace=True)

df_imp.head()
# Out:
#    Region    Fresh    Milk  Grocery  Frozen  Detergents_Paper  Delicassen
# 0     3.0  12669.0  9656.0   7561.0   214.0            2674.0      1338.0
# 1     3.0   7057.0  9810.0   9568.0  1762.0            3293.0      1776.0
# 2     3.0   6353.0  8808.0      NaN  2405.0            3516.0      7844.0
# 3     3.0  13265.0  1196.0   4221.0  6404.0             507.0      1788.0
# 4     3.0  22615.0  5410.0   7198.0  3915.0            1777.0      5185.0

# %%
df_imp.isna().sum()
# Out:
# Region               8
# Fresh               13
# Milk                15
# Grocery              9
# Frozen               8
# Detergents_Paper    10
# Delicassen          11
# dtype: int64

# %%
from sklearn.pipeline import Pipeline
from sklearn.impute import KNNImputer
from sklearn.preprocessing import StandardScaler

# Create the pipeline
pipeline = Pipeline([
    ('scaler', StandardScaler()),  # Step 1: StandardScaler for feature scaling
    ('imputer', KNNImputer(n_neighbors=5))  # Step 2: KNNImputer for missing value imputation
])

# Fit and transform the data using the pipeline
X_transformed = pipeline.fit_transform(df_imp)

# Creating dataframe
X_transformed = pd.DataFrame(X_transformed,columns=df_imp.columns)

X_transformed.head()
# Out:
#      Region     Fresh      Milk   Grocery    Frozen  Detergents_Paper  \
# 0  0.555438 -0.233395  0.187310 -0.319038 -0.554681         -0.272830
# 1  0.555438 -0.616431  0.204632 -0.139260 -0.281917         -0.165147
# 2  0.555438 -0.664481  0.091925  0.200717 -0.168617         -0.126353
# 3  0.555438 -0.192716 -0.764292 -0.618222  0.536025         -0.649809
# 4  0.555438  0.445450 -0.290291 -0.351554  0.097452         -0.428875
#
#    Delicassen
# 0   -0.175386
# 1   -0.051741
# 2    1.661231
# 3   -0.048353
# 4    0.910606

# %%
X_transformed.isna().sum()
# Out:
# Region              0
# Fresh               0
# Milk                0
# Grocery             0
# Frozen              0
# Detergents_Paper    0
# Delicassen          0
# dtype: int64
